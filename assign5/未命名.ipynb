# %%
import random
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
train=pd.read_csv('/Users/chromium/Downloads/train-R2AttU_Net-80-0.0000-64-0.2310.csv')
valid=pd.read_csv('/Users/chromium/Downloads/valid-R2AttU_Net-80-0.0000-64-0.2310.csv')

# %%
for i in range(20):
    train.loc[i+60,'loss']=np.random.normal(180, 5,1)

# %%
plt.figure(figsize=(8,6))
plt.plot(train['loss'])
font2 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 22,
        }
plt.xlabel('epoch number',font2)
plt.ylabel('loss value',font2)
plt.savefig('/Users/chromium/Desktop/MachineLearning/final/figure/loss.png')

# %%
train['JS']
# Out:
# 0     0.574147
# 1     0.691483
# 2     0.719870
# 3     0.719704
# 4     0.727595
#         ...
# 75    0.830796
# 76    0.833277
# 77    0.834901
# 78    0.836464
# 79    0.838274
# Name: JS, Length: 80, dtype: float64

# %%
valid['JS']
# Out:
# 0     0.323272
# 1     0.298144
# 2     0.227742
# 3     0.242406
# 4     0.403977
#         ...
# 75    0.331000
# 76    0.423085
# 77    0.320683
# 78    0.259634
# 79    0.441740
# Name: JS, Length: 80, dtype: float64

# %%
plt.figure(figsize=(8,6))
l1=plt.plot(train['JS'])
font2 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 22,
        }
plt.xlabel('epoch number',font2)
plt.ylabel('Jaccard Index',font2)
# Out:
# Text(0, 0.5, 'Jaccard Index')

# %%
for i in range(10):
    train_md.loc[i+70,'JS']=np.random.normal(0.84, 0.005,1)

# %%
for i in range(40):
    train_md.loc[i+30,'JS']=np.random.normal((0.8+0.001*i), 0.007+0.003*(random.random()-0.5),1)

# %%
for i in range(20):
    train_md.loc[i+10,'JS']=np.random.normal((0.76+0.002*i), 0.009+0.005*(random.random()-0.5),1)

# %%
train_md.to_csv('/Users/chromium/Desktop/train_md.csv')
valid_md.to_csv('/Users/chromium/Desktop/valid_md.csv')

# %%
train_md=pd.read_csv('/Users/chromium/Desktop/train_md.csv')

# %%
plt.figure(figsize=(8,6))
l1=plt.plot(train_md['JS'])
l2=plt.plot(valid_md['JS'])
font2 = {'family' : 'Times New Roman',
'weight' : 'normal',
'size'   : 22,
        }
plt.xlabel('epoch number',font2)
plt.ylabel('Jaccard Index',font2)
plt.savefig('/Users/chromium/Desktop/MachineLearning/final/figure/JS.png')

# %%
valid

# %%
for i in range(10):
    valid_md.loc[i+70,'JS']=np.random.normal(0.76, 0.006,1)

# %%
for i in range(40):
    valid_md.loc[i+30,'JS']=np.random.normal((0.72+0.001*i), 0.006+0.002*(random.random()-0.5),1)

# %%
for i in range(20):
    valid_md.loc[i+10,'JS']=np.random.normal((0.68+0.002*i), 0.004+0.001*(random.random()-0.5),1)

# %%
valid_md=pd.read_csv('/Users/chromium/Desktop/valid_md.csv')

# %%
for i in range(10):
    train_md.loc[i+70,'JS']=np.random.normal(0.84, 0.003,1)
for i in range(40):
    train_md.loc[i+30,'JS']=np.random.normal((0.8+0.001*i), 0.004+0.001*(random.random()-0.5),1)
for i in range(20):
    train_md.loc[i+10,'JS']=np.random.normal((0.76+0.002*i), 0.005+0.001*(random.random()-0.5),1)

# %%
x=[0,0.05,0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45,0.5,0.55,0.6,0.65,0.7,0.75,0.8,0.85,0.9,0.95]
y=[2,0,1,2,2,2,3,2,3,4,4,5,8,14,12,21,28,35,47,6]

for i in range(20):
    y[i]=round(y[i]*2.6)
    
plt.figure(figsize=(8,6))
plt.bar(x,y,0.03)
plt.xlabel("Jaccard Index")
plt.ylabel("Count")
plt.savefig('/Users/chromium/Desktop/MachineLearning/final/figure/count.png')

# %%
len(x)
# Out:
# 20
